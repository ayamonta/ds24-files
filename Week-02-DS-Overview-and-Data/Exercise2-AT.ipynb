# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.

import pandas as pd
import numpy as np
import os
import string

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = '~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)

# df.size  num of row x col  //  df.shape  row, col  //  df.ndim  array dimensions

print(f"(row, col): {df_food.shape}\ntotal: {df_food.size}")
# Out:
# (row, col): (125, 61)
# total: 7625

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
# df.info()
df_food.dtypes
# Out:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
# display(df_food)

weight_df = df_food[['calories_day', 'weight', 'Gender']]
display(weight_df)
# Out:
#      calories_day                   weight  Gender
# 0             NaN                      187       2
# 1             3.0                      155       1
# 2             4.0  I'm not answering this.       1
# 3             3.0            Not sure, 240       1
# 4             2.0                      190       1
# ..            ...                      ...     ...
# 120           4.0                      156       1
# 121           2.0                      180       1
# 122           NaN                      120       1
# 123           4.0                      135       2
# 124           NaN                      135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
# NaN = Not a Number || isnull is an alias for isna, so use isna
display(weight_df.dtypes)
weight_df.isna().sum()
# Out:
# calories_day    float64
# weight           object
# Gender            int64
# dtype: object
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
# axis:index -> drop rows containing missing values || how:any -> drop if any NA values are present
weight_df = weight_df.dropna(axis = 'index', how = 'any')
display(weight_df)

weight_df.isna().sum()
# Out:
#      calories_day                   weight  Gender
# 1             3.0                      155       1
# 2             4.0  I'm not answering this.       1
# 3             3.0            Not sure, 240       1
# 4             2.0                      190       1
# 5             3.0                      190       1
# ..            ...                      ...     ...
# 118           3.0                      140       1
# 119           3.0                      185       2
# 120           4.0                      156       1
# 121           2.0                      180       1
# 123           4.0                      135       2
#
# [104 rows x 3 columns]
# calories_day    0
# weight          0
# Gender          0
# dtype: int64

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.

# .loc[row_indexer,col_indexer] = value

weight_df["weight"] = pd.to_numeric(weight_df["weight"], errors = "coerce", downcast = "integer")
display(weight_df)

weight_df = weight_df.dropna(axis = 'index', how = 'any')
display(weight_df)
# Out:
#      calories_day  weight  Gender
# 1             3.0   155.0       1
# 2             4.0     NaN       1
# 3             3.0     NaN       1
# 4             2.0   190.0       1
# 5             3.0   190.0       1
# ..            ...     ...     ...
# 118           3.0   140.0       1
# 119           3.0   185.0       2
# 120           4.0   156.0       1
# 121           2.0   180.0       1
# 123           4.0   135.0       2
#
# [104 rows x 3 columns]
#      calories_day  weight  Gender
# 1             3.0   155.0       1
# 4             2.0   190.0       1
# 5             3.0   190.0       1
# 6             3.0   180.0       2
# 7             3.0   137.0       1
# ..            ...     ...     ...
# 118           3.0   140.0       1
# 119           3.0   185.0       2
# 120           4.0   156.0       1
# 121           2.0   180.0       1
# 123           4.0   135.0       2
#
# [101 rows x 3 columns]

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
weight_df.isna().sum()
# Out:
# calories_day    0
# weight          0
# Gender          0
# dtype: int64

# %%
# Savey save!

weight_df_rename = "food_coded_weight.csv"

weight_df.to_csv(weight_df_rename, index = False)

# %%
pd.read_csv("~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/food_coded_weight.csv")
# Out:
#      calories_day  weight  Gender
# 0             3.0   155.0       1
# 1             2.0   190.0       1
# 2             3.0   190.0       1
# 3             3.0   180.0       2
# 4             3.0   137.0       1
# ..            ...     ...     ...
# 96            3.0   140.0       1
# 97            3.0   185.0       2
# 98            4.0   156.0       1
# 99            2.0   180.0       1
# 100           4.0   135.0       2
#
# [101 rows x 3 columns]

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).

manager_salary_path = "~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv"

df_salary = pd.read_csv(manager_salary_path, sep = "\t")

display(df_salary)
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# ...

# %%
# manager_salary_oldname = "~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv"
# manager_salary_newnew = "~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data/ask-a-manager-salary-survey"

blk_list = "()"

salary_filename = "Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv"
salary_lower = salary_filename.lower()
print(salary_filename)
print(salary_lower)

salary_nospace = salary_lower.replace(" ", "_")
print(salary_nospace)

salary_symbol = ''.join(letter for letter in salary_nospace if letter not in blk_list)
print(salary_symbol)
# Out:
# Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv
# ask a manager salary survey 2021 (responses) - form responses 1.tsv
# ask_a_manager_salary_survey_2021_(responses)_-_form_responses_1.tsv
# ask_a_manager_salary_survey_2021_responses_-_form_responses_1.tsv

# %%
# salary_path = "~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv"
# salary_rn_path = os.path.join("~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data/", salary_symbol)
# print(salary_path)
# print(salary_rn_path)

# pd.read_csv(salary_path, sep="\t")
# # || rename or replace
# os.rename(salary_filename, salary_symbol)

# os.renames(salary_filename, salary_symbol)
# os.rename("data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv", salary_symbol)

# persistent error: Path/file does not exist -> error was that we weren't in the cwd

data_path = "/home/mouse/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data"
saved_cwd = os.getcwd()
print(saved_cwd)
os.chdir(data_path)
os.rename('Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', salary_symbol)
# Out:
# ~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv
# ~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data/ask_a_manager_salary_survey_2021_responses_-_form_responses_1.tsv
# /home/mouse/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data

# %%
os.chdir(saved_cwd)

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.

print(f"(row, col): {df_salary.shape}\ntotal: {df_salary.size}")
# Out:
# (row, col): (28062, 18)
# total: 505116

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

df_salary.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                object
# How old are you?                                                                                                                                                                                                                         object
# What industry do you work in?                                                                                                                                                                                                            object
# Job title                                                                                                                                                                                                                                object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed, gender, race

# SHOULD BE dictionary instead of list to avoid any incorrect column order

df_salary.columns = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed', 'gender', 'race']

# %%
df_salary
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                    Health care
#
#                                           title title_context   salary  \
# 0            Research and Instruction Librarian           NaN   55,000
# ...

# %%
# personal: Re-did column renaming with dictionary instead of list

import pandas as pd

manager_salary_path = "~/csc-assign/ds24-files/Week-02-DS-Overview-and-Data/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv"
df_salary2 = pd.read_csv(manager_salary_path, sep = "\t", quotechar = '"')
# encoding='utf-8', quoting=csv.QUOTE_NONE
display(df_salary2)
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# ...

# %%
df_salary2.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                object
# How old are you?                                                                                                                                                                                                                         object
# What industry do you work in?                                                                                                                                                                                                            object
# Job title                                                                                                                                                                                                                                object
# ...

# %%
correct_col_names = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed', 'gender', 'race']

col_names = list(df_salary2.columns)
display(col_names)
display(correct_col_names)
r"""If "Other," please indicate the currency here:"""
# Out:
# ['Timestamp',
#  'How old are you?',
#  'What industry do you work in?',
#  'Job title',
#  'If your job title needs additional context, please clarify here:',
#  "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)",
#  'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.',
#  'Please indicate the currency',
#  'If "Other," please indicate the currency here: ',
#  'If your income needs additional context, please provide it here:',
#  'What country do you work in?',
#  "If you're in the U.S., what state do you work in?",
#  'What city do you work in?',
#  'How many years of professional work experience do you have overall?',
# ...

# %%
# Can do it with list of column names
# UNFINISHED

for idx in range(len(col_names)):
    df_new = df_salary2.rename(columns={col_names[idx] : correct_col_names[idx]})
# display(df_salary2)
# len(col_names)
col_names[0]
correct_col_names[0]
# display(df_new)
# Out:
# 'timestamp'

# %%
# UNFINISHED

timestamp = "Timestamp"
age = "How old are you?"
industry = "What industry do you work in?"
title = "Job title"
title_context = "If your job title needs additional context, please clarify here:"
salary = "What is your annual salary? (You\'ll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)"
additional_compensation = "How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits."
currency = "Please indicate the currency"
other_currency = r"""If 'Other,' please indicate the currency here: """

df_new = df_salary2.rename({timestamp : 'timestamp',
                            age : 'age',
                            industry : 'industry',
                            title : 'title',
                            title_context : 'title_context',
                            salary : 'salary',
                            additional_compensation : 'additional_compensation',
                            currency : 'currency',
                            other_currency : 'other_currency'},
                            # 'salary_context',
                            # 'country',
                            # 'state',
                            # 'city',
                            # 'total_yoe',
                            # 'field_yoe',
                            # 'highest_education_completed',
                            # 'gender',
                            # 'race'},
                            axis = 'columns')

display(df_new)
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                    Health care
#
#                                           title title_context   salary  \
# 0            Research and Instruction Librarian           NaN   55,000
# ...

# %%
df_salary2
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# ...

# %%
df_new
# Out:
#                 timestamp    age  What industry do you work in?  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                    Health care
#
#                                       Job title  \
# 0            Research and Instruction Librarian
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.

display(df_salary.loc[ : , 'industry'].value_counts())
df_salary.loc[ : , 'industry'].value_counts()['Computing or Tech']
# Out:
# industry
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64
# 4699

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)

largest_idx = df_salary.loc[ : , 'industry'].value_counts()
largest_idx
# Out:
# industry
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64

# %%
largest_idx.nlargest(1).index
# Out:
# Index(['Computing or Tech'], dtype='object', name='industry')

# %%
df_salary[df_salary['industry'].isin(largest_idx.nlargest(1).index)]
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %%
df_salary_tech = df_salary[df_salary['industry'].isin(largest_idx.nlargest(1).index)]
df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check

df_salary_tech.loc[ : , 'industry'].value_counts()
# Out:
# industry
# Computing or Tech    4699
# Name: count, dtype: int64

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!

display(df_salary_tech['currency'].unique())

filter_usd = df_salary['currency'] == "USD"

df_salary_usd = df_salary.loc[filter_usd]
display(df_salary_usd)
# Out:
# array(['GBP', 'USD', 'CAD', 'EUR', 'Other', 'CHF', 'AUD/NZD', 'SEK',
#        'JPY', 'ZAR'], dtype=object)
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28052   7/3/2024 14:02:01  25-34              Computing or Tech
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
#
#                                         title title_context  salary  \
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

df_salary_usd['country'].value_counts()
# Out:
# country
# United States                                8989
# USA                                          7922
# US                                           2606
# United States                                 667
# U.S.                                          580
#                                              ...
# Cote d'Ivoire                                   1
# From Romania, but for an US based company       1
# Somalia                                         1
# Norway                                          1
# Burma                                           1
# Name: count, Length: 229, dtype: int64

# %%
# Get largest 5 indices, for next Q
country_idx = df_salary_usd['country'].value_counts()
country_idx
# Out:
# country
# United States                                8989
# USA                                          7922
# US                                           2606
# United States                                 667
# U.S.                                          580
#                                              ...
# Cote d'Ivoire                                   1
# From Romania, but for an US based company       1
# Somalia                                         1
# Norway                                          1
# Burma                                           1
# Name: count, Length: 229, dtype: int64

# %%
country_idx.nlargest(5)
# Out:
# country
# United States     8989
# USA               7922
# US                2606
# United States      667
# U.S.               580
# Name: count, dtype: int64

# %%
country_idx.nlargest(5).index
# Out:
# Index(['United States', 'USA', 'US', 'United States ', 'U.S.'], dtype='object', name='country')

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.

df_salary_amer = df_salary_usd[df_salary_usd['country'].isin(country_idx.nlargest(5).index)]
display(df_salary_amer)
df_salary_amer['country'].value_counts()
# Out:
#                 timestamp    age                              industry  \
# 0      4/27/2021 11:02:10  25-34          Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34         Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                            Nonprofits
# 4      4/27/2021 11:02:42  25-34         Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34          Education (Higher Education)
# ...                   ...    ...                                   ...
# 28042  5/26/2024 15:34:27  25-34  Government and Public Administration
# 28043   5/27/2024 2:47:26  25-34                     Computing or Tech
# 28044   6/3/2024 16:15:43  18-24                     Computing or Tech
# 28057  7/12/2024 22:52:01  35-44                           Health care
# 28058  7/23/2024 17:51:03  25-34                     Computing or Tech
#
#                                     title  \
# 0      Research and Instruction Librarian
# ...

# %%
df_salary_amer.loc[ : , 'country'] = "US"
display(df_salary_amer)
df_salary_amer['country'].value_counts()
# Out:
#                 timestamp    age                              industry  \
# 0      4/27/2021 11:02:10  25-34          Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34         Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                            Nonprofits
# 4      4/27/2021 11:02:42  25-34         Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34          Education (Higher Education)
# ...                   ...    ...                                   ...
# 28042  5/26/2024 15:34:27  25-34  Government and Public Administration
# 28043   5/27/2024 2:47:26  25-34                     Computing or Tech
# 28044   6/3/2024 16:15:43  18-24                     Computing or Tech
# 28057  7/12/2024 22:52:01  35-44                           Health care
# 28058  7/23/2024 17:51:03  25-34                     Computing or Tech
#
#                                     title  \
# 0      Research and Instruction Librarian
# ...

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

display(df_salary_amer.loc[ : , 'country'].unique())
df_salary_amer.loc[ : , 'country'].value_counts()
# Out:
# array(['US'], dtype=object)
# country
# US    20764
# Name: count, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

df_salary_amer.groupby('state')['salary'].agg(['min', 'mean', 'max'])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.

display(df_salary_amer.dtypes)
# Out:
# timestamp                       object
# age                             object
# industry                        object
# title                           object
# title_context                   object
# salary                          object
# additional_compensation        float64
# currency                        object
# other_currency                  object
# salary_context                  object
# country                         object
# state                           object
# city                            object
# total_yoe                       object
# field_yoe                       object
# highest_education_completed     object
# gender                          object
# race                            object
# dtype: object

# %%
df_salary_amer_moneys = df_salary_amer
df_salary_amer_moneys.loc[ : , "salary"] = pd.to_numeric(df_salary_amer["salary"], errors = "coerce", downcast = "integer")
display(df_salary_amer_moneys.dtypes)
# Out:
# timestamp                       object
# age                             object
# industry                        object
# title                           object
# title_context                   object
# salary                         float64
# additional_compensation        float64
# currency                        object
# other_currency                  object
# salary_context                  object
# country                         object
# state                           object
# city                            object
# total_yoe                       object
# field_yoe                       object
# highest_education_completed     object
# gender                          object
# race                            object
# dtype: object

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

df_salary_amer_moneys.groupby('state')['salary'].agg(['min', 'mean', 'max'])
# Out:
#                                    min          mean        max
# state
# Alabama                           54.0  67898.906250   125500.0
# Alabama, California            29120.0  29120.000000    29120.0
# Alabama, District of Columbia      NaN           NaN        NaN
# Alabama, Kansas                    NaN           NaN        NaN
# Alabama, Minnesota, Nevada         NaN           NaN        NaN
# ...                                ...           ...        ...
# Virginia                          57.0  98212.867021  1300000.0
# Washington                        72.0  97039.335878   300000.0
# West Virginia                      0.0  49076.428571   120000.0
# Wisconsin                          1.0  83048.391304   920000.0
# Wyoming                        42500.0  63578.500000    98000.0
#
# [115 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

filter_2000s = "2021" in df_salary_amer_moneys["timestamp"] or "2022" in df_salary_amer_moneys["timestamp"]

# %%
# error: 'False: boolean label can not be used without a boolean index'
# df_salary_amer_moneys.loc[filter_2000s, : ]

# df_salary_amer_moneys[("2021" in df_salary_amer_moneys)]
# df_salary_amer_moneys[df_salary_amer_moneys["timestamp"].isin(["2021", "2022"])]
df_salary_relevant = df_salary_amer_moneys[df_salary_amer_moneys["timestamp"].str.contains("2021" or "2022" or "2023")]
display(df_salary_relevant)
# Out:
#                  timestamp    age                       industry  \
# 0       4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2       4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3       4/27/2021 11:02:41  25-34                     Nonprofits
# 4       4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5       4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                    ...    ...                            ...
# 27590  12/28/2021 17:50:32  45-54   Education (Higher Education)
# 27591  12/28/2021 18:11:28  35-44   Education (Higher Education)
# 27592  12/28/2021 18:15:37  45-54                            NaN
# 27594   12/29/2021 6:55:29  25-34   Engineering or Manufacturing
# 27595  12/29/2021 16:12:49  25-34                    Health care
#
#                                     title  \
# 0      Research and Instruction Librarian
# 2                    Marketing Specialist
# 3                         Program Manager
# ...

# %%
df_salary_relevant["timestamp"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         4/27/2021 11:02:10
# 2         4/27/2021 11:02:38
# 3         4/27/2021 11:02:41
# 4         4/27/2021 11:02:42
# 5         4/27/2021 11:02:46
#                 ...
# 27590    12/28/2021 17:50:32
# 27591    12/28/2021 18:11:28
# 27592    12/28/2021 18:15:37
# 27594     12/29/2021 6:55:29
# 27595    12/29/2021 16:12:49
# Name: timestamp, Length: 20459, dtype: object>

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
