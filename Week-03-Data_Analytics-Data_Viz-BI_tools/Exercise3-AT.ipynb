# %%
import geoplot

import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
import pandas as pd

! pip install geopandas
! pip install geoplot

import geopandas
# import geoplot
import pandas as pd
import numpy as np
from shapely.geometry import Point, Polygon
# import matplotlib.pyplot as plt

import random

# from matplotlib import colors
# from matplotlib.ticker import PercentFormatter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 KB 7.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /home/weasel/.local/lib/python3.10/site-packages (from geopandas) (24.1)
# Collecting pyproj>=3.3.0
#   Downloading pyproj-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 26.6 MB/s eta 0:00:0000:0100:01
# Collecting shapely>=2.0.0
#   Downloading shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 21.1 MB/s eta 0:00:0000:0100:01
# Collecting pyogrio>=0.7.2
#   Downloading pyogrio-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 35.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.22 in /home/weasel/.local/lib/python3.10/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: pandas>=1.4.0 in /home/weasel/.local/lib/python3.10/site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /home/weasel/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/weasel/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/weasel/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: certifi in /home/weasel/.local/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.9.0 pyproj-3.6.1 shapely-2.0.6
# Defaulting to user installation because normal site-packages is not writeable
# Collecting geoplot
#   Downloading geoplot-0.5.1-py3-none-any.whl (28 kB)
# Collecting contextily>=1.0.0
#   Downloading contextily-1.6.2-py3-none-any.whl (17 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 7.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas in /home/weasel/.local/lib/python3.10/site-packages (from geoplot) (2.2.2)
# Requirement already satisfied: geopandas>=0.9.0 in /home/weasel/.local/lib/python3.10/site-packages (from geoplot) (1.0.1)
# Collecting mapclassify>=2.1
#   Downloading mapclassify-2.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 KB 4.5 MB/s eta 0:00:00
# Collecting cartopy
#   Downloading Cartopy-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 28.5 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib>=3.1.2
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 33.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests in /home/weasel/.local/lib/python3.10/site-packages (from contextily>=1.0.0->geoplot) (2.32.3)
# Collecting xyzservices
#   Downloading xyzservices-2024.9.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 KB 11.1 MB/s eta 0:00:00
# Collecting joblib
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 KB 19.1 MB/s eta 0:00:00
# Collecting rasterio
#   Downloading rasterio-1.3.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 28.2 MB/s eta 0:00:0000:0100:01
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 16.9 MB/s eta 0:00:00
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in /home/weasel/.local/lib/python3.10/site-packages (from contextily>=1.0.0->geoplot) (10.4.0)
# Requirement already satisfied: numpy>=1.22 in /home/weasel/.local/lib/python3.10/site-packages (from geopandas>=0.9.0->geoplot) (2.0.1)
# Requirement already satisfied: pyproj>=3.3.0 in /home/weasel/.local/lib/python3.10/site-packages (from geopandas>=0.9.0->geoplot) (3.6.1)
# Requirement already satisfied: packaging in /home/weasel/.local/lib/python3.10/site-packages (from geopandas>=0.9.0->geoplot) (24.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/weasel/.local/lib/python3.10/site-packages (from geopandas>=0.9.0->geoplot) (0.9.0)
# Requirement already satisfied: shapely>=2.0.0 in /home/weasel/.local/lib/python3.10/site-packages (from geopandas>=0.9.0->geoplot) (2.0.6)
# Collecting networkx>=2.7
#   Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 31.1 MB/s eta 0:00:00a 0:00:01
# Collecting scipy>=1.8
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 26.9 MB/s eta 0:00:0000:0100:01
# Collecting scikit-learn>=1.0
#   Downloading scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 33.9 MB/s eta 0:00:0000:0100:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.53.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 33.4 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.9 MB/s eta 0:00:00a 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.1.2->geoplot) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/weasel/.local/lib/python3.10/site-packages (from matplotlib>=3.1.2->geoplot) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 KB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in /home/weasel/.local/lib/python3.10/site-packages (from pandas->geoplot) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /home/weasel/.local/lib/python3.10/site-packages (from pandas->geoplot) (2024.1)
# Collecting pyshp>=2.3
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 KB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /home/weasel/.local/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas>=0.9.0->geoplot) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->geoplot) (1.16.0)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 KB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: click>=3.0 in /home/weasel/.local/lib/python3.10/site-packages (from mercantile->contextily>=1.0.0->geoplot) (8.1.7)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from rasterio->contextily>=1.0.0->geoplot) (59.6.0)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: attrs in /home/weasel/.local/lib/python3.10/site-packages (from rasterio->contextily>=1.0.0->geoplot) (24.2.0)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/weasel/.local/lib/python3.10/site-packages (from requests->contextily>=1.0.0->geoplot) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/weasel/.local/lib/python3.10/site-packages (from requests->contextily>=1.0.0->geoplot) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/weasel/.local/lib/python3.10/site-packages (from requests->contextily>=1.0.0->geoplot) (3.7)
# Installing collected packages: xyzservices, threadpoolctl, snuggs, scipy, pyshp, networkx, mercantile, kiwisolver, joblib, geographiclib, fonttools, cycler, contourpy, cligj, click-plugins, affine, scikit-learn, rasterio, matplotlib, geopy, seaborn, mapclassify, contextily, cartopy, geoplot
# Successfully installed affine-2.4.0 cartopy-0.23.0 click-plugins-1.1.1 cligj-0.7.2 contextily-1.6.2 contourpy-1.3.0 cycler-0.12.1 fonttools-4.53.1 geographiclib-2.0 geoplot-0.5.1 geopy-2.4.1 joblib-1.4.2 kiwisolver-1.4.7 mapclassify-2.8.0 matplotlib-3.9.2 mercantile-1.2.1 networkx-3.3 pyshp-2.3.1 rasterio-1.3.11 scikit-learn-1.5.2 scipy-1.14.1 seaborn-0.13.2 snuggs-1.4.7 threadpoolctl-3.5.0 xyzservices-2024.9.0

# %%
# Import pandas
import pandas as pd

# %%
# Load in the listings data
df=pd.read_csv('data/listings.csv')
df
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ   12941925
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# 0         Jennifer           Manhattan             Midtown  40.75362
# 1      LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 2            Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 3          Rebecca            Brooklyn         Sunset Park  40.66120
# 4         Shunichi           Manhattan      Hell's Kitchen  40.76489
# ...            ...                 ...                 ...       ...
# 46522        Brian           Manhattan            Gramercy  40.73433
# 46523        Salar           Manhattan  Washington Heights  40.85820
# 46524       Nicole            Brooklyn       East Flatbush  40.65399
# 46525     Fernando           Manhattan     Upper West Side  40.78731
# 46526       Marina            Brooklyn           Gravesend  40.59945
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.98377  Entire home/apt    175               3                 48
# 1      -73.95976  Entire home/apt     75               1                340
# 2      -73.95596     Private room     60              29                 50
# 3      -73.99423  Entire home/apt    175              14                  1
# 4      -73.98493     Private room     65               2                473
# ...          ...              ...    ...             ...                ...
# 46522  -73.98383  Entire home/apt    145               7                  0
# 46523  -73.92733  Entire home/apt     87               6                  0
# 46524  -73.93287     Private room     59               3                  0
# 46525  -73.97029  Entire home/apt     80              30                  0
# 46526  -73.98209     Private room     66               1                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2019-11-04               0.37                               2
# 1      2020-08-01               4.75                               1
# 2      2019-12-02               0.37                               1
# 3      2014-01-02               0.01                               1
# 4      2020-03-15               3.44                               1
# ...           ...                ...                             ...
# 46522         NaN                NaN                               1
# 46523         NaN                NaN                               2
# 46524         NaN                NaN                               1
# 46525         NaN                NaN                               1
# 46526         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   265
# 2                   365
# 3                   295
# 4                   340
# ...                 ...
# 46522               164
# 46523                85
# 46524                90
# 46525               113
# 46526                38
#
# [46527 rows x 16 columns]

# %%
# Load in the listings data
df_orig=pd.read_csv('data/listings.csv')
df_orig
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ   12941925
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# 0         Jennifer           Manhattan             Midtown  40.75362
# 1      LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 2            Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 3          Rebecca            Brooklyn         Sunset Park  40.66120
# 4         Shunichi           Manhattan      Hell's Kitchen  40.76489
# ...            ...                 ...                 ...       ...
# 46522        Brian           Manhattan            Gramercy  40.73433
# 46523        Salar           Manhattan  Washington Heights  40.85820
# 46524       Nicole            Brooklyn       East Flatbush  40.65399
# 46525     Fernando           Manhattan     Upper West Side  40.78731
# 46526       Marina            Brooklyn           Gravesend  40.59945
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.98377  Entire home/apt    175               3                 48
# 1      -73.95976  Entire home/apt     75               1                340
# 2      -73.95596     Private room     60              29                 50
# 3      -73.99423  Entire home/apt    175              14                  1
# 4      -73.98493     Private room     65               2                473
# ...          ...              ...    ...             ...                ...
# 46522  -73.98383  Entire home/apt    145               7                  0
# 46523  -73.92733  Entire home/apt     87               6                  0
# 46524  -73.93287     Private room     59               3                  0
# 46525  -73.97029  Entire home/apt     80              30                  0
# 46526  -73.98209     Private room     66               1                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2019-11-04               0.37                               2
# 1      2020-08-01               4.75                               1
# 2      2019-12-02               0.37                               1
# 3      2014-01-02               0.01                               1
# 4      2020-03-15               3.44                               1
# ...           ...                ...                             ...
# 46522         NaN                NaN                               1
# 46523         NaN                NaN                               2
# 46524         NaN                NaN                               1
# 46525         NaN                NaN                               1
# 46526         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   265
# 2                   365
# 3                   295
# 4                   340
# ...                 ...
# 46522               164
# 46523                85
# 46524                90
# 46525               113
# 46526                38
#
# [46527 rows x 16 columns]

# %%
df_orig.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# ####  Exercise 1: Create a bar chart and dataframe of top 10 Neigborhoods that have the most expensive listsings on average.
# Our goal is to make a chart reflecting the top 10 most expensive Neighborhoods.
# This is a little dubious - we assign "expensive" by calculating the average cost of
# an AirBnB in each neighborhood.
#
# 1. Make a dataframe that sorts the neighborhood field by decending price.
# 1. Use head to cut back top the top 10
# 1. Use pandas.plot.barh to generate a histogram (see [this](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.barh.html) wiki for details on pandas.plot.barh)
# 1. Display the data that you used to create the bar chart as a table with neighborhood and average price as the columns.  You want this to match the pivot that you create in youur dashboard

# %%
# dataframe that sorts `neighborhood` col by descending 'price' col. use groupby
# use head to show top 10, from filter above
# NOTE: The result of groupby is a separate kind of object, a GroupBy object. You must apply, transform, or filter to get back to a DataFrame or Series.

# df_sort.describe()
df_gb = df_orig.groupby(by = ['neighbourhood'])
display(f'df_gb: {df_gb}')
display(df_gb['price'].sum())
display(df_gb['price'].sum().sort_values(ascending = False))

df_sort = df_orig.groupby(by = ['neighbourhood'])['price'].sum().sort_values(ascending = False)
display(df_sort)


# ^ testing
# v answer


df_sort = df_orig.groupby(by = ['neighbourhood'])['price'].mean().round(0).astype(int).sort_values(ascending = False)
display(df_sort)

# Convert to DataFrame
df_new = pd.DataFrame(df_sort)
# Reset the index
df_new = df_new.reset_index()
df_new = df_new.head(10)
display(df_new.head(10))
# Out:
# 'df_gb: <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f779b55d480>'
# neighbourhood
# Allerton            3991
# Arden Heights        596
# Arrochar            2501
# Arverne            17684
# Astoria            85038
#                    ...
# Windsor Terrace    18813
# Woodhaven           6767
# Woodlawn            1190
# Woodrow              700
# Woodside           21147
# Name: price, Length: 222, dtype: int64
# neighbourhood
# Midtown                       477376
# Williamsburg                  461720
# Hell's Kitchen                375019
# Bedford-Stuyvesant            367114
# Upper West Side               351453
#                                ...
# Graniteville                     153
# Bull's Head                      149
# Gerritsen Beach                  100
# Rossville                         61
# Bay Terrace, Staten Island        55
# Name: price, Length: 222, dtype: int64
# neighbourhood
# Midtown                       477376
# Williamsburg                  461720
# Hell's Kitchen                375019
# Bedford-Stuyvesant            367114
# Upper West Side               351453
#                                ...
# Graniteville                     153
# Bull's Head                      149
# Gerritsen Beach                  100
# Rossville                         61
# Bay Terrace, Staten Island        55
# Name: price, Length: 222, dtype: int64
# neighbourhood
# Fort Wadsworth       800
# Woodrow              700
# Sea Gate             418
# Tribeca              381
# Flatiron District    367
#                     ...
# Soundview             52
# New Brighton          52
# Port Richmond         51
# Bull's Head           50
# South Beach           45
# Name: price, Length: 222, dtype: int64
#         neighbourhood  price
# 0      Fort Wadsworth    800
# 1             Woodrow    700
# 2            Sea Gate    418
# 3             Tribeca    381
# 4   Flatiron District    367
# 5           Briarwood    366
# 6  Financial District    335
# 7         Willowbrook    309
# 8         Tottenville    309
# 9        Prince's Bay    300

# %%
# use `pandas.plot.barh`to generate histogram
df_new.plot(kind='barh', x='neighbourhood', y='price')
# df_new.plot.barh(x='neighbourhood', y='price')
# df_new.plot.barh()
# Out:
# <Axes: ylabel='neighbourhood'>

# %%
# display table with 'neighborhood' and 'average price' columns.
display(df_new.rename({'price': 'average_price'}, axis='columns'))
# Out:
#         neighbourhood  average_price
# 0      Fort Wadsworth            800
# 1             Woodrow            700
# 2            Sea Gate            418
# 3             Tribeca            381
# 4   Flatiron District            367
# 5           Briarwood            366
# 6  Financial District            335
# 7         Willowbrook            309
# 8         Tottenville            309
# 9        Prince's Bay            300

# %%
# our goal is to make a chart reflecting the top 10 most expensive Neighborhoods
# This is a little dubious - we assign "expensive" by calculating the average cost of
# an AirBnB in each neighborhood, then we take the top ten and weight each slice
# by the average value.
#
# make a dataframe that sorts the neighborhood field by decending price.
# Use head to cut back top the top 10. Then, use df.plot.barh to generate a histogram.

# %%
# Now, display the top 10 datframe you created as a table with columns
# neighbourhood and price

# %% [markdown]
# ####  Exercise 2: Create a bar chart and dataframe of top 10 Neigborhoods that have the LEAST expensive listsings on average.
#
# Do the same thing you just did, but get the 10 least expensive neighborhoods.  Sort them from lowest average price to highest.  Bew wure to provide a pivot table.

# %%
# Here we make the same chart using the bottom 10 Neighborhoods
# by average price.  We sort ascending in this one.

df_ascend = df_orig.groupby(by = ['neighbourhood'])['price'].mean().round(0).astype(int).sort_values(ascending = True)
display(df_ascend)

# Convert to DataFrame
df_new_ascend = pd.DataFrame(df_ascend)
# Reset the index
df_new_ascend = df_new_ascend.reset_index()
df_new_ascend = df_new_ascend.head(10)
display(df_new_ascend.head(10))
# Out:
# neighbourhood
# South Beach           45
# Bull's Head           50
# Port Richmond         51
# Soundview             52
# New Brighton          52
#                     ...
# Flatiron District    367
# Tribeca              381
# Sea Gate             418
# Woodrow              700
# Fort Wadsworth       800
# Name: price, Length: 222, dtype: int64
#                 neighbourhood  price
# 0                 South Beach     45
# 1                 Bull's Head     50
# 2               Port Richmond     51
# 3                   Soundview     52
# 4                New Brighton     52
# 5  Bay Terrace, Staten Island     55
# 6                 Hunts Point     57
# 7                  Grant City     58
# 8          University Heights     58
# 9                   Olinville     59

# %%
df_new_ascend.plot(kind='barh', x='neighbourhood', y='price')
# Out:
# <Axes: ylabel='neighbourhood'>

# %%
# we also would like to have the corresponding pivot table of the lowest 10
display(df_new_ascend)
# Out:
#                 neighbourhood  price
# 0                 South Beach     45
# 1                 Bull's Head     50
# 2               Port Richmond     51
# 3                   Soundview     52
# 4                New Brighton     52
# 5  Bay Terrace, Staten Island     55
# 6                 Hunts Point     57
# 7                  Grant City     58
# 8          University Heights     58
# 9                   Olinville     59

# %% [markdown]
# #  Now make all four widgets (the two charts and the two dataframes) in a Tableau dashboard!
